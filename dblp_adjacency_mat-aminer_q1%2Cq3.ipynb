# %%
import pandas as pd
import json
import math as m
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn import model_selection
import collections
import re
import networkx as nx
import nltk
from nltk.util import ngrams
from sklearn.model_selection import train_test_split
# from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.base import BaseEstimator, TransformerMixin

# %%
data_json = []
with open('data/dblp-ref-0.json') as f:
    for line in f:
        data_json.append(json.loads(line))

# %%
df = pd.DataFrame(data_json)

# %%
df = df[df['abstract'].notnull()]

# %%
parentdomain = {
    "coding theory" : "mathematical foundations",
    "game theory" : "mathematical foundations",
    "graph theory" : "mathematical foundations",
    "mathematical logic" : "mathematical foundations",
    "boolean logic" : "mathematical foundations",
    "number theory" : "mathematical foundations",
    "mathematical foundations" : "mathematical foundations",
    "algorithms" : "algorithms and data structures",
    "data structures" : "algorithms and data structures",
    "algorithms and data structures" : "algorithms and data structures",
    "automated reasoning" : "artificial intelligence",
    "computer vision" : "artificial intelligence",
    "machine learning" : "artificial intelligence",
    "evolutionary computing" : "artificial intelligence",
    "natural language processing" : "artificial intelligence",    
    "artificial intelligence" : "artificial intelligence",
    "neural network" : "artificial intelligence",
    "speech processing" : "artificial intelligence",
    "information retrieval" : "artificial intelligence",
    "data mining" : "artificial intelligence",
    "robotics" : "artificial intelligence",
    "networking" : "communication and security",
    "computer networks" : "communication and security",
    "communication networks" : "communication and security",
    "cryptography" : "communication and security",
    "communication and security" : "communication and security",
    "network protocols" : "communication and security",
    "network attacks" : "communication and security",
    "operating systems" : "computer architecture",
    "computer architecture" : "computer architecture",
    "image processing" : "computer graphics",
    "information visualization" : "computer graphics",
    "visualization" : "computer graphics",
    "visualisation" : "computer graphics",
    "computer graphics" : "computer graphics",
    "parallel computing" : "concurrent, parallel, and distributed systems",
    "concurrency" : "concurrent, parallel, and distributed systems",
    "distributed computing" : "concurrent, parallel, and distributed systems",
    "concurrent, parallel, and distributed systems" : "concurrent, parallel, and distributed systems",
    "relational databases" : "databases",
    "structured storage" : "databases",
    "databases" : "databases",
    "compiler theory" : "programming languages and compilers",
    "programming language" : "programming languages and compilers",
    "programming language pragmatics" : "programming languages and compilers",
    "programming language theory" : "programming languages and compilers",
    "formal semantics" : "programming languages and compilers",
    "type theory" : "programming languages and compilers",
    "programming languages and compilers" : "programming languages and compilers",
    "computational science" : "scientific computing",
    "numerical analysis" : "scientific computing",
    "symbolic computation " : "scientific computing",
    "computational physics" : "scientific computing",
    "computational chemistry" : "scientific computing",
    "bioinformatics" : "scientific computing",
    "computational biology" : "scientific computing",
    "computational neuroscience" : "scientific computing",
    "scientific computing" : "scientific computing",
    "formal methods" : "software engineering",
    "algorithm design" : "software engineering",
    "computer programming" : "software engineering",
    "human–computer interaction" : "software engineering",
    "reverse engineering" : "software engineering",
    "software engineering" : "software engineering",
    "automata theory " : "theory of computation",
    "computability theory" : "theory of computation",
    "computational complexity theory" : "theory of computation",
    "quantum computing" : "theory of computation",
    "theory of computation" : "theory of computation",   
}

# %%
df
# Out:
#                                                  abstract  \
# 0       The purpose of this study is to develop a lear...
# 1       This paper describes the design and implementa...
# 2       This article applied GARCH model instead AR or...
# 10      Recent achievements in Natural Language Proces...
# 12      Recently, Bridges and Reich introduced the con...
# 13      Most applications of the abstract interpretati...
# 14      Three speech training systems for hearing-impa...
# 16      This paper focuses on knowledge engineering fo...
# 20      Embedded systems often have limited amounts of...
# 22      Xax is a browser plugin model that enables dev...
# 23      In recent years, most of mobile phones have a ...
# 26      Previous language modeling approaches to infor...
# 29      Spatial encryption is a generic public-key cry...
# 31      In system operations the term rollback is ofte...
# 34      Business strategy should be well understood in...
# 35      FTP Mirror Tracker is a software package (writ...
# 36      There are a number of alternative techniques f...
# 43      Breast cancer is the most common form of cance...
# 45      The development of an automated system for the...
# 49      Quality specified image retrieval is helpful t...
# 57      We discuss traveling wave solutions to the Yuk...
# 61      In this paper, we investigate the multi-layer ...
# 64      The paper discusses the design principles and ...
# 65      State-space explosion is a major obstacle in v...
# 66      We focus on covariance criteria for flnding a ...
# 68      In recent years, several advanced methods for ...
# 69      This paper presents an experimental evaluation...
# 73      The paper describes user behavior as a result ...
# 78      The acquisition of concepts induced by structu...
# 81      We study a hypergraph transversal computation:...
# ...                                                   ...
# 999969  An $SIR$ infectious diseases model with disper...
# 999970  Purpose#R##N#A near real-time three-dimensiona...
# 999971  A Bluetooth ad hoc network can be formed by in...
# 999972  Social media, e.g. Weblog and Internet forum, ...
# 999973  Wireless Mesh networks (WMN) typically rely on...
# 999974  To improve the shortcomings of long arbitratio...
# 999975  The Drosophila eggshell constitutes a remarkab...
# 999976  This paper is devoted to attenuation of uncert...
# 999977  In this letter we develop a new generalization...
# 999978  In order to estimate the Hurst exponent of lon...
# 999979  This paper aims to evaluate the accuracy of op...
# 999980  We present a risk management framework which a...
# 999981  National competitiveness is a measure of the r...
# 999982  Multiple-valued logics have long been used, of...
# 999983  In this paper we present a concurrent implemen...
# 999984  Persuasive Technology has the potential to inf...
# 999985  We describe an efficient method of combining t...
# 999986  Wireless sensor networks, with their low cost,...
# 999987  Scagnostics (Scatterplot Diagnostics) were dev...
# 999988  This paper deals with direction estimation of ...
# 999989  The ability to generate entangled photon pairs...
# 999990  Both disturbance rejection and human-like moti...
# 999991  Nowadays, with the expansion of telemedicine n...
# 999992  In this paper we will present an overview of o...
# 999993  A finitek-net of ordern is an incidence struct...
# 999994  A new non-invasive method for delineation of l...
# 999996  In the last few years, workflow systems have b...
# 999997  There are many different designs for audio amp...
# 999998  This paper proposes a language acquisition fra...
# 999999  Abstract   This thesis investigates the mathem...
#
#                                                   authors  \
# 0       [Makoto Satoh, Ryo Muramatsu, Mizue Kayama, Ka...
# 1                             [Gareth Beale, Graeme Earl]
# 2       [Altaf Hossain, Faisal Zaman, Mohammed Nasser,...
# 10      [Ankita Brahmachari, Priya Singh, Avdhesh Garg...
# 12                [Alvaro L. Islas, Constance M. Schober]
# 13                        [Patrick Cousot, Radhia Cousot]
# 14                [Minoru Shigenaga, Yoshihiro Sekiguchi]
# 16      [Efthymios Alepis, Maria Virvou, Katerina Kaba...
# 22      Leveraging legacy code to deploy desktop appli...
# 23      A pedestrian navigation method for user's safe...
# 26      Word pairs in language modeling for informatio...
# 29                   Leakage-Resilient spatial encryption
# 31      On system rollback and totalized fields: An al...
# 34      Model-Driven Strategic Awareness: From a Unifi...
# 35            FTP Mirror Tracker: A Few Steps Towards URN
# 36      Information Systems Uncertainty Design and Imp...
# 43      Breast Cancer Identification Based on Thermal ...
# 45      Automated Object Identification and Position E...
# 49      Quality Assessment on User Generated Image for...
# 57      Traveling wave solutions of the n-dimensional ...
# 61      Multi-layer topology preserving mapping for K-...
# 64       A general semantic analyser for data base access
# 65      Interval Abstraction Refinement for Model Chec...
# 66                     Kernel PLS variants for regression
# 68      Two notes from experimental study on image ste...
# 69      Experimental Validation of a Rapid, Adaptive R...
# 73      Monetization as a Motivator for the Freemium E...
# 78      Learning of abstractions from structural descr...
# 81      Hypergraph Transversal Computation with Binary...
# ...                                                   ...
# 999969  Global Stability for an SIR Infectious Disease...
# 999970  Positioning error evaluation of GPU-based 3D u...
# 999971  Performance of a new Bluetooth scatternet form...
# 999972            Detect Events on Noisy Textual Datasets
# 999973  Mitigating the impact of ambient noise on Wire...
# 999974  HIGH SPEED MULTI-RESOURCE ARBITER WITH ACTIVE ...
# 999975  A discrete model of Drosophila eggshell patter...
# 999976  LMI-based design of multichannel anisotropic s...
# 999977  A generalized differential transform method fo...
# 999978             Estimation of Hurst exponent revisited
# 999979  A Fast Alignment Scheme for Automatic OCR Eval...
# 999980  Risk management in dynamic role based access c...
# 999981  Measuring the national competitiveness of Sout...
# 999982      Digital Simulation with Multiple Logic Values
# 999983  Shared memory genetic algorithms in a multi-ag...
# 999984  Influencing interaction: development of the de...
# 999985  Cooperative-Competitive Algorithms for Evoluti...
# 999986  Low complexity, losless ECG data compression a...
# 999987  Transforming Scagnostics to Reveal Hidden Feat...
# 999988  Modified IQML and weighted subspace fitting wi...
# 999989      Entanglement Distribution in Optical Networks
# 999990  Bipedal walking with toe-off, heel-strike and ...
# 999991  Introducing a new algorithm for medical image ...
# 999992     Texture, illumination, and material perception
# 999993                               Nets and their codes
# 999994  Delineation of malignant skin tumors by hypers...
# 999996    Distributed workflow management: the TEAM model
# 999997    Class-D Audio Amplifiers with Negative Feedback
# 999998  A simulation study exploring the role of cultu...
# 999999                 Continuous Domains in Logical Form
#
#                                                     venue  year
# 0       international conference on human-computer int...  2013
# 1                 visual analytics science and technology  2011
# 2            pattern recognition and machine intelligence  2009
# 10                                                         2013
# 12      international conference on conceptual structures  2002
# 13                                                         1991
# 14      international joint conference on artificial i...  1979
# 16      joint conference on knowledge-based software e...  2008
# 20                       european symposium on algorithms  2004
# 22            operating systems design and implementation  2008
# 23      international conference on human computer int...  2013
# 26                                                         2004
# 29                                                         2012
# 31         The Journal of Logic and Algebraic Programming  2011
# 34                                                         2012
# 35      usenix large installation systems administrati...  2000
# 36                                                         2014
# 43                                                         2013
# 45            international conference on computer vision  2008
# 49                      conference on multimedia modeling  2013
# 57                            Applied Mathematics Letters  2012
# 61      intelligent data engineering and automated lea...  2011
# 64      international joint conference on artificial i...  1981
# 65          formal modeling and analysis of timed systems  2014
# 66      the european symposium on artificial neural ne...  2003
# 68      international conference on intelligent computing  2013
# 69                                                         2014
# 73                           arXiv: Computers and Society  2015
# 78      international joint conference on artificial i...  1979
# 81      symposium on experimental and efficient algori...  2013
# ...                                                   ...   ...
# 999969            computational sciences and optimization  2012
# 999970            computer assisted radiology and surgery  2013
# 999971             mobile ad hoc networking and computing  2001
# 999972                        asia-pacific web conference  2010
# 999973                    dependable systems and networks  2012
# 999974        Journal of Circuits, Systems, and Computers  2010
# 999975                         PLOS Computational Biology  2014
# 999976                                                     2012
# 999977                        Applied Mathematics Letters  2008
# 999978           Computational Statistics & Data Analysis  2007
# 999979  international conference on document analysis ...  2011
# 999980  international conference on digital informatio...  2010
# 999981           European Journal of Operational Research  2008
# 999982  IEEE Transactions on Computer-Aided Design of ...  1986
# 999983    genetic and evolutionary computation conference  2010
# 999984  international conference on persuasive technology  2009
# 999985                          Neural Processing Letters  1999
# 999986                     Studia Informatica Universalis  2013
# 999987  IEEE Transactions on Visualization and Compute...  2014
# 999988                                  Signal Processing  1999
# 999989  IEEE Journal of Selected Topics in Quantum Ele...  2015
# 999990  ieee-ras international conference on humanoid ...  2014
# 999991                                                     2013
# 999992                                Proceedings of SPIE  2015
# 999993                    Designs, Codes and Cryptography  1993
# 999994           Biomedical Signal Processing and Control  2015
# 999996                    cooperative information systems  1998
# 999997                Siam Journal on Applied Mathematics  2005
# 999998                                 Connection Science  2010
# 999999   Electronic Notes in Theoretical Computer Science  2002
#
# [753646 rows x 8 columns]

# %%
df_copy = df.copy()
def getdomainlist(row):
    abst = row['abstract'] if type(row['abstract']) != float else  ""
    venue = row['venue'] if type(row['venue']) != float else  ""
    
    text = abst + " " + row['title'] + " " + venue
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    tokens = [token for token in text.split(" ") if token != ""]
    output1 = list(ngrams(tokens, 1))
    output2 = list(ngrams(tokens, 2))
    output3 = list(ngrams(tokens, 3))
    output = []
    for words in output1:
        output.append(' '.join(words))
    for words in output2:
        output.append(' '.join(words))
    for words in output3:
        output.append(' '.join(words))
    domainlist = set()
    for word in output:
        if word in parentdomain:
            domainlist.add(parentdomain[word])
    if len(domainlist) > 0:
        return list(domainlist)[0]
    else:
        return ""

df_copy['domain'] = df_copy.apply(getdomainlist, axis = 1)

# %%
dffinal = df_copy[df_copy['domain'].map(lambda x: len(x) >0)]

# %%
dffinal['text'] = dffinal[['abstract', 'title', 'venue']].apply(lambda x: ' '.join(x), axis=1)
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train, X_test, y_train, y_test = train_test_split(dffinal['text'].head(50000), dffinal['domain'].head(50000), random_state = 0)

pipeline = Pipeline([('vect', CountVectorizer(stop_words='english')),
                     ('tfidf', TfidfTransformer()),
                     ('clf', SGDClassifier(loss='hinge'))
                     ])

parameters = {
    'vect__max_df': (0.5, 0.75, 1.0),
    # 'vect__max_features': (None, 5000, 10000, 50000),
    'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    # 'tfidf__use_idf': (True, False),
    # 'tfidf__norm': ('l1', 'l2'),
    'clf__max_iter': (5,),
    'clf__alpha': (0.00001, 0.000001),
    'clf__penalty': ('l2', 'elasticnet'),
    # 'clf__max_iter': (10, 50, 80),
}

grid_search = GridSearchCV(pipeline, parameters, cv=5,n_jobs=10,
                               verbose=1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=10)]: Done 120 out of 120 | elapsed:  8.3min finished
# /jet/var/python/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         ...m_state=None, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=10,
#        param_grid={'vect__max_df': (0.5, 0.75, 1.0), 'vect__ngram_range': ((1, 1), (1, 2)), 'clf__max_iter': (5,), 'clf__alpha': (1e-05, 1e-06), 'clf__penalty': ('l2', 'elasticnet')},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
df['text'] = df[['abstract', 'title', 'venue']].apply(lambda x: ' '.join(x), axis=1)

# %%
len(df)
# Out:
# 753646

# %%
df
# Out:
#                                                  abstract  \
# 0       The purpose of this study is to develop a lear...
# 1       This paper describes the design and implementa...
# 2       This article applied GARCH model instead AR or...
# 10      Recent achievements in Natural Language Proces...
# 12      Recently, Bridges and Reich introduced the con...
# 13      Most applications of the abstract interpretati...
# 14      Three speech training systems for hearing-impa...
# 16      This paper focuses on knowledge engineering fo...
# 20      Embedded systems often have limited amounts of...
# 22      Xax is a browser plugin model that enables dev...
# 23      In recent years, most of mobile phones have a ...
# 26      Previous language modeling approaches to infor...
# 29      Spatial encryption is a generic public-key cry...
# 31      In system operations the term rollback is ofte...
# 34      Business strategy should be well understood in...
# 35      FTP Mirror Tracker is a software package (writ...
# 36      There are a number of alternative techniques f...
# 43      Breast cancer is the most common form of cance...
# 45      The development of an automated system for the...
# 49      Quality specified image retrieval is helpful t...
# 57      We discuss traveling wave solutions to the Yuk...
# 61      In this paper, we investigate the multi-layer ...
# 64      The paper discusses the design principles and ...
# 65      State-space explosion is a major obstacle in v...
# 66      We focus on covariance criteria for flnding a ...
# 68      In recent years, several advanced methods for ...
# 69      This paper presents an experimental evaluation...
# 73      The paper describes user behavior as a result ...
# 78      The acquisition of concepts induced by structu...
# 81      We study a hypergraph transversal computation:...
# ...                                                   ...
# 999969  An $SIR$ infectious diseases model with disper...
# 999970  Purpose#R##N#A near real-time three-dimensiona...
# 999971  A Bluetooth ad hoc network can be formed by in...
# 999972  Social media, e.g. Weblog and Internet forum, ...
# 999973  Wireless Mesh networks (WMN) typically rely on...
# 999974  To improve the shortcomings of long arbitratio...
# 999975  The Drosophila eggshell constitutes a remarkab...
# 999976  This paper is devoted to attenuation of uncert...
# 999977  In this letter we develop a new generalization...
# 999978  In order to estimate the Hurst exponent of lon...
# 999979  This paper aims to evaluate the accuracy of op...
# 999980  We present a risk management framework which a...
# 999981  National competitiveness is a measure of the r...
# 999982  Multiple-valued logics have long been used, of...
# 999983  In this paper we present a concurrent implemen...
# 999984  Persuasive Technology has the potential to inf...
# 999985  We describe an efficient method of combining t...
# 999986  Wireless sensor networks, with their low cost,...
# 999987  Scagnostics (Scatterplot Diagnostics) were dev...
# 999988  This paper deals with direction estimation of ...
# 999989  The ability to generate entangled photon pairs...
# 999990  Both disturbance rejection and human-like moti...
# 999991  Nowadays, with the expansion of telemedicine n...
# 999992  In this paper we will present an overview of o...
# 999993  A finitek-net of ordern is an incidence struct...
# 999994  A new non-invasive method for delineation of l...
# 999996  In the last few years, workflow systems have b...
# 999997  There are many different designs for audio amp...
# 999998  This paper proposes a language acquisition fra...
# 999999  Abstract   This thesis investigates the mathem...
#
#                                                   authors  \
# 0       [Makoto Satoh, Ryo Muramatsu, Mizue Kayama, Ka...
# 1                             [Gareth Beale, Graeme Earl]
# 2       [Altaf Hossain, Faisal Zaman, Mohammed Nasser,...
# 10      [Ankita Brahmachari, Priya Singh, Avdhesh Garg...
# 12                [Alvaro L. Islas, Constance M. Schober]
# 13                        [Patrick Cousot, Radhia Cousot]
# 14                [Minoru Shigenaga, Yoshihiro Sekiguchi]
# 16      [Efthymios Alepis, Maria Virvou, Katerina Kaba...
# 20      [Matias Madou, Bjorn De Sutter, Bruno De Bussc...
# 22      [John R. Douceur, Jeremy Elson, Jon Howell, Ja...
# 23                    [Hiroshi Furukawa, Yutaka Nakamura]
# 26      [Carmen Fernández-Daza Álvarez, Philippe Langl...
# 29                        [Michel Abdalla, Jill-Jênn Vie]
# 31                          [Mark Burgess, Alva L. Couch]
# 34      [Constantinos Giannoulis, Jelena Zdravkovic, M...
# 35                      [Alexei Novikov, Martin Hamilton]
# 36                [Theresa Beaubouef, Frederick E. Petry]
# 43      [Bartosz Krawczyk, Gerald Schaefer, Shao Ying ...
# 45      [J. Niblock, Jian-Xun Peng, Karen McMenemy, Ge...
# 49            [Qiong Liu, You Yang, Xu Wang, Liujuan Cao]
# 57                                 [Robert A. Van Gorder]
# 61                 [Ying Wu, Thomas K. Doyle, Colin Fyfe]
# 64                           [B. K. Bog, K. Sparck Jones]
# 65      [Sine Viesmose Birch, Thomas Stig Jacobsen, Ja...
# 66      [Luc Hoegaerts, Johan A. K. Suykens, Joos Vand...
# 68                 [Qingxiao Guan, Jing Dong, Tieniu Tan]
# 69      [Mike D. Rinderknecht, Werner L. Popp, Olivier...
# 73      [Ilya V. Osipov, Anna Y. Prasikova, Alex A. Vo...
# 78                                     [Pierre E. Bonzon]
# 81                                        [Takahisa Toda]
# ...                                                   ...
# 999969                [Luju Liu, Weiyun Cai, Shifei Wang]
# 999970                     [Ikuma Sato, Ryoichi Nakamura]
# 999971                          [A. Mehta, Kai-Yeung Siu]
# 999972  [Sen Yang, Xueqi Cheng, You Chen, Gaolin Fang,...
# 999973  [Jesus Friginal, Juan Carlos Ruiz, David de An...
# 999974  [Xuguang Guan, Zhangming Zhu, Duan Zhou, Yinta...
# 999975  [A. Faure, Barbara Mi Vreede, Élio Sucena, Cla...
# 999976  [Michael M. Tchaikovsky, A. P. Kurdyukov, V. M...
# 999977                       [Zaid Odibat, Shaher Momani]
# 999990  [264a36aa-166a-4ce6-98b1-6de61915c8df, 2e7b424...
# 999991  [13816cd8-cd4f-4f67-8da5-921bdce68d35, 60ef385...
# 999992             [ce986080-4b28-453c-bd97-521a2fccbf46]
# 999993  [db7dd70d-1c54-4ef6-bcf0-7cba156ce604, f1d929b...
# 999994  [2bf40147-087c-4fb1-89e3-6e7a91d19b97, 6876ea7...
# 999996  [02763555-4d84-49fa-b6aa-00171c832dc0, 4be4595...
# 999997             [3059f971-f49e-4a49-a1e5-82ea4e8f6879]
# 999998  [207c4e1c-52f4-4737-9cd9-1db86b33d580, 55c81e3...
# 999999  [1cddd8b1-8262-4351-9606-e1eb710f2159, 2026759...
#
#                                                     title  \
# 0       Preliminary Design of a Network Protocol Learn...
# 1       A methodology for the physically accurate visu...
# 2       Comparison of GARCH, Neural Network and Suppor...
# 10      Identifying Psychological Theme Words from Emo...
# 12      Multisymplectic Spectral Methods for the Gross...
# 13      Relational Abstract Interpretation of Higher O...
# 14      Speech training systems using lateral shapes o...
# 16      Knowledge Engineering for Affective Bi-Modal I...
# 20                  Link-time compaction of MIPS programs
# 22      Leveraging legacy code to deploy desktop appli...
# 23      A pedestrian navigation method for user's safe...
# 26      Word pairs in language modeling for informatio...
# 29                   Leakage-Resilient spatial encryption
# 31      On system rollback and totalized fields: An al...
# 34      Model-Driven Strategic Awareness: From a Unifi...
# 35            FTP Mirror Tracker: A Few Steps Towards URN
# 36      Information Systems Uncertainty Design and Imp...
# 43      Breast Cancer Identification Based on Thermal ...
# 45      Automated Object Identification and Position E...
# 49      Quality Assessment on User Generated Image for...
# 57      Traveling wave solutions of the n-dimensional ...
# 61      Multi-layer topology preserving mapping for K-...
# 64       A general semantic analyser for data base access
# 65      Interval Abstraction Refinement for Model Chec...
# 66                     Kernel PLS variants for regression
# 68      Two notes from experimental study on image ste...
# 69      Experimental Validation of a Rapid, Adaptive R...
# 73      Monetization as a Motivator for the Freemium E...
# 78      Learning of abstractions from structural descr...
# 81      Hypergraph Transversal Computation with Binary...
# ...                                                   ...
# 999969  Global Stability for an SIR Infectious Disease...
# 999970  Positioning error evaluation of GPU-based 3D u...
# 999971  Performance of a new Bluetooth scatternet form...
# 999972            Detect Events on Noisy Textual Datasets
# 999973  Mitigating the impact of ambient noise on Wire...
# 999974  HIGH SPEED MULTI-RESOURCE ARBITER WITH ACTIVE ...
# 999975  A discrete model of Drosophila eggshell patter...
# 999976  LMI-based design of multichannel anisotropic s...
# 999977  A generalized differential transform method fo...
# 999978             Estimation of Hurst exponent revisited
# 999979  A Fast Alignment Scheme for Automatic OCR Eval...
# 999980  Risk management in dynamic role based access c...
# 999981  Measuring the national competitiveness of Sout...
# 999982      Digital Simulation with Multiple Logic Values
# 999983  Shared memory genetic algorithms in a multi-ag...
# 999984  Influencing interaction: development of the de...
# 999985  Cooperative-Competitive Algorithms for Evoluti...
# 999986  Low complexity, losless ECG data compression a...
# 999987  Transforming Scagnostics to Reveal Hidden Feat...
# 999988  Modified IQML and weighted subspace fitting wi...
# 999989      Entanglement Distribution in Optical Networks
# 999990  Bipedal walking with toe-off, heel-strike and ...
# 999991  Introducing a new algorithm for medical image ...
# 999992     Texture, illumination, and material perception
# 999993                               Nets and their codes
# 999994  Delineation of malignant skin tumors by hypers...
# 999996    Distributed workflow management: the TEAM model
# 999997    Class-D Audio Amplifiers with Negative Feedback
# 999998  A simulation study exploring the role of cultu...
# 999999                 Continuous Domains in Logical Form
#
#                                                     venue  year  \
# 0       international conference on human-computer int...  2013
# 1                 visual analytics science and technology  2011
# 2            pattern recognition and machine intelligence  2009
# 10                                                         2013
# 12      international conference on conceptual structures  2002
# 13                                                         1991
# 14      international joint conference on artificial i...  1979
# 16      joint conference on knowledge-based software e...  2008
# 20                       european symposium on algorithms  2004
# 22            operating systems design and implementation  2008
# 23      international conference on human computer int...  2013
# 26                                                         2004
# 29                                                         2012
# 31         The Journal of Logic and Algebraic Programming  2011
# 34                                                         2012
# 35      usenix large installation systems administrati...  2000
# 36                                                         2014
# 43                                                         2013
# 45            international conference on computer vision  2008
# 49                      conference on multimedia modeling  2013
# 57                            Applied Mathematics Letters  2012
# 61      intelligent data engineering and automated lea...  2011
# 64      international joint conference on artificial i...  1981
# 65          formal modeling and analysis of timed systems  2014
# 66      the european symposium on artificial neural ne...  2003
# 68      international conference on intelligent computing  2013
# 69                                                         2014
# 73                           arXiv: Computers and Society  2015
# 78      international joint conference on artificial i...  1979
# 81      symposium on experimental and efficient algori...  2013
# ...                                                   ...   ...
# 999969            computational sciences and optimization  2012
# 999970            computer assisted radiology and surgery  2013
# 999971             mobile ad hoc networking and computing  2001
# 999972                        asia-pacific web conference  2010
# 999973                    dependable systems and networks  2012
# 999974        Journal of Circuits, Systems, and Computers  2010
# 999975                         PLOS Computational Biology  2014
# 999976                                                     2012
# 999977                        Applied Mathematics Letters  2008
# 999978           Computational Statistics & Data Analysis  2007
# 999979  international conference on document analysis ...  2011
# 999980  international conference on digital informatio...  2010
# 999981           European Journal of Operational Research  2008
# 999982  IEEE Transactions on Computer-Aided Design of ...  1986
# 999983    genetic and evolutionary computation conference  2010
# 999984  international conference on persuasive technology  2009
# 999985                          Neural Processing Letters  1999
# 999986                     Studia Informatica Universalis  2013
# 999987  IEEE Transactions on Visualization and Compute...  2014
# 999988                                  Signal Processing  1999
# 999989  IEEE Journal of Selected Topics in Quantum Ele...  2015
# 999990  ieee-ras international conference on humanoid ...  2014
# 999991                                                     2013
# 999992                                Proceedings of SPIE  2015
# 999993                    Designs, Codes and Cryptography  1993
# 999994           Biomedical Signal Processing and Control  2015
# 999996                    cooperative information systems  1998
# 999997                Siam Journal on Applied Mathematics  2005
# 999998                                 Connection Science  2010
# 999999   Electronic Notes in Theoretical Computer Science  2002
#
#                                                      text
# 0       The purpose of this study is to develop a lear...
# 1       This paper describes the design and implementa...
# 2       This article applied GARCH model instead AR or...
# 10      Recent achievements in Natural Language Proces...
# 12      Recently, Bridges and Reich introduced the con...
# 13      Most applications of the abstract interpretati...
# 14      Three speech training systems for hearing-impa...
# 16      This paper focuses on knowledge engineering fo...
# 20      Embedded systems often have limited amounts of...
# 22      Xax is a browser plugin model that enables dev...
# 23      In recent years, most of mobile phones have a ...
# 26      Previous language modeling approaches to infor...
# 29      Spatial encryption is a generic public-key cry...
# 31      In system operations the term rollback is ofte...
# 34      Business strategy should be well understood in...
# 35      FTP Mirror Tracker is a software package (writ...
# 36      There are a number of alternative techniques f...
# 43      Breast cancer is the most common form of cance...
# 45      The development of an automated system for the...
# 49      Quality specified image retrieval is helpful t...
# 57      We discuss traveling wave solutions to the Yuk...
# 61      In this paper, we investigate the multi-layer ...
# 64      The paper discusses the design principles and ...
# 65      State-space explosion is a major obstacle in v...
# 66      We focus on covariance criteria for flnding a ...
# 68      In recent years, several advanced methods for ...
# 69      This paper presents an experimental evaluation...
# 73      The paper describes user behavior as a result ...
# 78      The acquisition of concepts induced by structu...
# 81      We study a hypergraph transversal computation:...
# ...                                                   ...
# 999969  An $SIR$ infectious diseases model with disper...
# 999970  Purpose#R##N#A near real-time three-dimensiona...
# 999971  A Bluetooth ad hoc network can be formed by in...
# 999972  Social media, e.g. Weblog and Internet forum, ...
# 999973  Wireless Mesh networks (WMN) typically rely on...
# 999974  To improve the shortcomings of long arbitratio...
# 999975  The Drosophila eggshell constitutes a remarkab...
# 999976  This paper is devoted to attenuation of uncert...
# 999977  In this letter we develop a new generalization...
# 999978  In order to estimate the Hurst exponent of lon...
# 999979  This paper aims to evaluate the accuracy of op...
# 999980  We present a risk management framework which a...
# 999981  National competitiveness is a measure of the r...
# 999982  Multiple-valued logics have long been used, of...
# 999983  In this paper we present a concurrent implemen...
# 999984  Persuasive Technology has the potential to inf...
# 999985  We describe an efficient method of combining t...
# 999986  Wireless sensor networks, with their low cost,...
# 999987  Scagnostics (Scatterplot Diagnostics) were dev...
# 999988  This paper deals with direction estimation of ...
# 999989  The ability to generate entangled photon pairs...
# 999990  Both disturbance rejection and human-like moti...
# 999991  Nowadays, with the expansion of telemedicine n...
# 999992  In this paper we will present an overview of o...
# 999993  A finitek-net of ordern is an incidence struct...
# 999994  A new non-invasive method for delineation of l...
# 999996  In the last few years, workflow systems have b...
# 999997  There are many different designs for audio amp...
# 999998  This paper proposes a language acquisition fra...
# 999999  Abstract   This thesis investigates the mathem...
#
# [753646 rows x 9 columns]

# %%
answer = grid_search.predict(df['text'].values.tolist())

# %%
df['domain'] = answer.tolist()

# %%
df1 = df.head(10000)

# %%
atod = {}
def domains(row):
    for i in row['authors']:
        if i not in atod:
            atod[i] = []
            atod[i].append(row['domain'])
        else:
            atod[i].append(row['domain'])
        
x = df1.apply(domains, axis = 1)

# %%
paper_citations = df1['n_citation'].values.tolist()

# %%
author_matrix = df1['authors'].values.tolist()

# %%
result = set(x for l in author_matrix for x in l)

# %%
result = list(result)

# %%
len(result)
# Out:
# 26699

# %%
name_map = {}
name_map_reverse = {}
for index, i in enumerate(result):
    name_map[i] = index
    name_map_reverse[index] = i

# %%
ptoa = {}
atop = {}
ptoc = {}
author_to_papersum = {}
author_to_papercite = {}
author_to_author = {}
for index, x in enumerate(author_matrix):
    ptoa[index] = x
    for author in x:
        if author not in atop:
            atop[author] = []
        if author not in author_to_author:
            author_to_author[author] = {}
        for aut in x:
            if aut != author :
                if aut not in author_to_author[author]:
                    author_to_author[author][aut] = 1
                else:
                    author_to_author[author][aut] +=1
        atop[author].append(index)
for index, i in enumerate(paper_citations):
    ptoc[index] = i
for author in name_map.keys():
    author_to_papersum[author] = len(atop[author])
for author in name_map.keys():
    author_to_papercite[author] = 0
    for v in atop[author]:
        author_to_papercite[author] += ptoc[v]
aut_year = df1[['authors', 'year']].values.tolist()
author_years = {}
for index, x in enumerate(aut_year):
    year = int(x[1])
    authors = x[0]
    for author in authors:
        if author not in author_years:
            author_years[author] = {}
            author_years[author]['max'] = year
            author_years[author]['min'] = year
        else:
            author_years[author]['max'] = max(author_years[author]['max'], year)
            author_years[author]['min'] = min(author_years[author]['min'], year)

# %%
adj = {}
for x in atop.keys():
    if name_map[x] not in adj:
        adj[name_map[x]] = set()
    for paper in atop[x]:
        for aut in ptoa[paper]:
            if aut == x: continue 
            adj[name_map[x]].add(name_map[aut])
from collections import OrderedDict
adj_sorted = sorted(adj.items(), key=lambda kv: kv[0])
adj1 = OrderedDict()
for x in adj_sorted:
    key = x[0]
    value = x[1]
    adj1[key] = value

# %%
def hIndex(citations):
    h = [0] * (len(citations) + 1)
    for i in citations:
        if i > len(citations):
            h[-1] += 1
        else:
            h[i] += 1
    sum_c = 0
    for i,j in enumerate(h[::-1]):
            sum_c = sum_c + j
            if sum_c >= len(citations) - i:
                return(len(citations) - i)
    return 0

# %%
atoh = {}
for x in atop:
    l = []
    for p in atop[x]:
        l.append(ptoc[p])
    atoh[x] = hIndex(l)
atoh1 = {}
for author in adj1:
    author_name = name_map_reverse[author]
    atoh1[author_name] = atoh[author_name]

# %%
sociability = {}
for author1 in adj1:
    author_name = name_map_reverse[author1]
    temp_social = 0
    for coauthor in author_to_author[author_name]:
        temp_social += m.log(author_to_author[author_name][coauthor])
    sociability[author_name] = 1 + temp_social

# %%
longevity = {}
for author1 in adj1:
    author_name = name_map_reverse[author1]
    longevity[author_name] = author_years[author_name]['max'] - author_years[author_name]['min'] + 1

# %%
atod1 = {}
for author1 in adj1:
    author_name = name_map_reverse[author1]
    atod1[author_name] = atod[author_name]

# %%
diversity = {}
for index in atod1:
    diversity[index] = len(atod1[index])

# %%
i10index = {}
for i in atop:
    temp = 0
    for pid in atop[i]:
        if ptoc[pid] > 10:
            temp += 1
    i10index[i] = temp
i10_index = {}
for author1 in adj1:
    author_name = name_map_reverse[author1]
    i10_index[author_name] = i10index[author_name]

# %%
def gindex(citations):
    citations = sorted(citations,reverse = False)
    i = 0
    sum_c = 0
    ans = 0
    while(i < len(citations)):
        sum_c += citations[i]
        if sum_c >= (i+1)*(i+1): 
            ans = i+1
        i += 1
    return ans

# %%
atog = {}
for x in atop:
    l = []
    for p in atop[x]:
        l.append(ptoc[p])
    atog[x] = gindex(l)
atog1 = {}
for author in adj1:
    author_name = name_map_reverse[author]
    atog1[author_name] = atog[author_name]

# %%
len(adj)
# Out:
# 26699

# %%
adj1
# Out:
# OrderedDict([(0, {12331, 14580, 18452, 22158}),
#              (1, {14351}),
#              (2, {10212}),
#              (3, {364, 5420, 6443, 9520}),
#              (4, {17251}),
#              (5, {9435}),
#              (6, {3614, 10922, 15114, 20961, 23220, 25660}),
#              (7, {11143, 17805}),
#              (8, {3441, 12905, 13109}),
#              (9, {3540, 17867, 21374}),
#              (10, {18198, 21575, 26324}),
#              (11, {4386, 9021, 13339, 22508}),
#              (12, {1491}),
#              (13, set()),
#              (14, {17450, 21407}),
#              (15, {6434, 15830, 25497}),
#              (16, {10997, 17983}),
#              (17, {8764, 18080, 22862}),
#              (18, {18370}),
#              (19, {11733}),
#              (20, {6989, 7604, 11503, 16196}),
#              (21,
#               {1096,
#                5546,
#                5736,
#                5821,
#                5986,
#                7882,
#                9404,
#                10051,
#                11763,
#                13801,
#                17585,
#                22111,
#                22131,
#                24285}),
#              (22, {1988, 3066, 16314, 17777, 24132}),
#              (23, {6346, 8475, 20702}),
#              (24, {3337, 7231, 12162, 18476, 20210}),
#              (25, {16766}),
#              (26, {12621, 17895}),
#              (27, {21442}),
#              (28, {250, 12375, 14155, 14760, 24692}),
#              (29, {2380, 6118, 11742, 17645, 17846, 25843}),
#              (30, {12418, 19861}),
#              (31, {6077, 9150, 23502}),
#              (32, {5567, 9502}),
#              (33, {18648}),
#              (34, {16762, 18328, 22333}),
#              (35, {5956, 6144, 13774, 16124, 16519, 18909}),
#              (36, {15111}),
#              (37, {1509, 1641, 5670}),
#              (38, {8951, 17707}),
#              (39, set()),
#              (40, {25997, 26309}),
#              (41, {2674, 5760}),
#              (42, {10017, 10937, 10943, 11209}),
#              (43, {6165}),
#              (44, {5392, 18155}),
#              (45, {220, 7865, 12333, 13540, 16039, 19469, 23248}),
#              (46, {2947, 3789, 6078, 13847}),
#              (47, {11965, 13354, 24200}),
#              (48, {1872, 9486, 17325, 19408, 25560}),
#              (49, {2038, 2177, 24593, 24734}),
#              (50, {25430}),
#              (51, set()),
#              (52, {142, 16589, 23181}),
#              (53, {1097, 6817}),
#              (54, {2232, 24152}),
#              (55, {4385, 5218, 13671, 15542, 20811, 22828}),
#              (56, {3557, 5565, 21321}),
#              (57, {21971}),
#              (58, {3440, 14806, 15414, 20087, 22460, 24252}),
#              (59, {2274, 3509, 7493, 15173, 22597, 25291}),
#              (60, {436, 2408, 4473, 7180, 10824, 19800, 22062}),
#              (61, {18549}),
#              (62, {954, 1580, 3069, 3294}),
#              (63, {4809, 21648}),
#              (64, {6699}),
#              (65, {1459, 8735, 15274, 17940, 22105, 22972}),
#              (66, {3255, 4464, 9826, 21408}),
#              (67, {2279, 3451, 6545, 22399}),
#              (68, set()),
#              (69, {4226, 10495, 13945, 17134, 17455, 24884}),
#              (70, {20231}),
#              (71, {18792, 24645}),
#              (282, {1856, 19284}),
#              (283, {2834}),
#              (284, {605}),
#              (285, {14911}),
#              (286, {9552, 9680, 21343}),
#              (287, {5295, 8667, 9145, 15152, 18810, 22177}),
#              (288, {947, 8642, 13384}),
#              (289, {3374, 12472, 14883}),
#              (290, {1072, 2199, 3067, 3607, 8729, 9189, 14832, 16200}),
#              (291, {13013}),
#              (292, {16658}),
#              (293, {16521, 22664}),
#              (294, {14919, 15111}),
#              (295, {1466, 18115, 20721, 23893}),
#              (296, {24999}),
#              (297, {8350, 21467}),
#              (298, {26670}),
#              (299, {16685}),
#              (300, {3697, 6117, 9461, 22507, 22670}),
#              (301, {6490, 23610, 25119}),
#              (302, {339, 3819, 10098, 12218}),
#              (303, {17259}),
#              (304, {2905, 4991, 10574, 12929, 18260, 23280}),
#              (305, {4668, 11221, 22024}),
#              (306, {22818}),
#              (307, {17920, 21947}),
#              (308, {379}),
#              (309, {5800, 8177, 9601, 16594, 22667, 23975}),
#              (310, {26091}),
#              (311, {7106}),
#              (312,
#               {6399, 12573, 16090, 17445, 20485, 20809, 22513, 23797, 25693}),
#              (313, {3255, 4174, 15371, 19115}),
#              (314, {6011, 13290, 17386, 25818}),
#              (315, {5437, 14311}),
#              (316, {828, 9518, 25913}),
#              (317, {16166}),
#              (318, {19497}),
#              (319, {10483, 13678, 16342, 18538, 20695}),
#              (320,
#               {223,
#                568,
#                631,
#                659,
#                885,
#                1352,
#                1911,
#                2107,
#                2248,
#                3046,
#                3092,
#                3443,
#                3541,
#                4451,
#                5075,
#                5422,
#                6512,
#                6765,
#                7073,
#                7158,
#                7243,
#                7650,
#                7984,
#                8027,
#                8249,
#                8463,
#                8651,
#                8655,
#                9045,
#                9987,
#                10067,
#                10713,
#                11121,
#                11140,
#                11337,
#                11968,
#                13171,
#                13328,
#                13820,
#                14077,
#                14268,
#                14663,
#                14947,
#                15350,
#                15995,
#                16154,
#                16520,
#                17496,
#                18982,
#                19131,
#                19380,
#                20262,
#                20579,
#                20838,
#                21152,
#                21705,
#                21707,
#                21842,
#                22660,
#                23720,
#                24483,
#                24536,
#                24741,
#                26297,
#                26464,
#                26565}),
#              (321, {1890, 18603, 22850}),
#              (322, {1998, 19677}),
#              (323, {12738, 13499}),
#              (324, {3221, 11153, 13126, 15772}),
#              (325, {2170, 4551, 21740, 24528}),
#              (326, {7790, 8160, 21414}),
#              (327, set()),
#              (328, {2486, 17155, 20650, 26344}),
#              (329, {2202, 19118, 19271, 22381}),
#              (330, {2655, 4631}),
#              (331, {3182, 7284, 10387, 19464}),
#              (332, {2877, 4272, 6213, 15571, 21665}),
#              (333, {23656}),
#              (334, {3007, 4884, 6570, 6668, 10376}),
#              (335, {15292, 20274, 25855}),
#              (336, {2504, 22029}),
#              (337, {1695, 3997, 15809, 19336, 19678}),
#              (338, {6104, 9846, 14899}),
#              (339, {302, 3819, 10098, 12218, 22228, 23761}),
#              (340, {3273, 14314}),
#              (341, {16619, 17762}),
#              (342, set()),
#              (343, {6372, 18905, 21834}),
#                11337,
#                13171,
#                13328,
#                13820,
#                14077,
#                14268,
#                14663,
#                14947,
#                15350,
#                16154,
#                16520,
#                17496,
#                18982,
#                19131,
#                19380,
#                20262,
#                20579,
#                20838,
#                21152,
#                21705,
#                21707,
#                21842,
#                22660,
#                23720,
#                24483,
#                24536,
#                24741,
#                26297,
#                26464,
#                26565}),
#              (632, {21313, 26428}),
#              (633, {6136, 8401, 8844, 15513}),
#              (634, {214, 7851, 11341, 17226, 17818, 22910}),
#              (635, {5718, 9257, 13709, 17402, 23457}),
#              (636, {8667, 11043, 12330, 12459, 12875}),
#              (637, {19194, 21711}),
#              (638,
#               {2033,
#                2050,
#                3378,
#                5781,
#                8908,
#                13030,
#                20293,
#                22930,
#                24755,
#                25110,
#                25347}),
#              (639, {18463, 20363, 23952}),
#              (640, {2203, 4469, 5268, 10774}),
#              (641, set()),
#              (642, {1884, 3562, 5359, 12636, 21911}),
#              (643, {5206, 9220, 9912, 15182, 23676, 25793}),
#              (644, {15609, 19149, 20871}),
#              (645, {10632, 24520, 26139}),
#              (646, {4352, 6963}),
#              (647, {1279, 1493}),
#              (648, {11578, 20167, 22897}),
#              (649, {13305, 14371, 19744}),
#              (650, {5133, 18294}),
#              (651, {7574, 22011}),
#              (652, {8694, 22165}),
#              (653,
#               {4504,
#                6968,
#                9289,
#                11989,
#                12252,
#                14858,
#                15700,
#                22578,
#                22817,
#                23198,
#                24465}),
#              (654, {1421, 4326}),
#              (655, {5910, 24613}),
#              (656, {23792, 25454}),
#              (657, {1156, 7422, 9622, 11035}),
#              (658, {1812, 11430, 13116, 19701}),
#              (659,
#               {223,
#                320,
#                568,
#                631,
#                885,
#                1352,
#                1911,
#                2107,
#                2248,
#                3046,
#                3092,
#                3443,
#                4451,
#                5075,
#                5422,
#                6512,
#                6765,
#                7073,
#                7158,
#                7243,
#                7650,
#                8027,
#                8249,
#                8463,
#                8651,
#                9045,
#                10067,
#                10713,
#                11121,
#                11140,
#                11337,
#                13171,
#                13328,
#                13820,
#                14077,
#                14268,
#                14663,
#                14947,
#                15350,
#                16154,
#                16520,
#                17496,
#                18982,
#                19131,
#                19380,
#                20262,
#                20579,
#                20838,
#                21152,
#                21705,
#                21707,
#                21842,
#                22660,
#                23720,
#                24483,
#                24536,
#                24741,
#                26297,
#                26464,
#                26565}),
#              (660, {6112, 10872, 24001, 26128}),
#              (661, {7875, 24079}),
#              (662, {3296, 24407}),
#              (663, {22925, 24887}),
#              (664, set()),
#              (665, set()),
#              (666, {5219, 8124, 18532, 21048, 21893}),
#              (667, {4370}),
#              (668, {1125, 1771, 4222, 6993, 8683, 12672, 13446}),
#              (669, set()),
#              (670, {1932, 15132}),
#              (671, {8525}),
#              (672, {12658, 14268, 23124, 23126}),
#              (673, {13343, 16734, 16834, 20887}),
#              (674, {2778, 23569}),
#              (675, {12232, 17030}),
#              (676, {4885, 12676, 13125}),
#              (677, {681, 1399, 2617, 4751, 14663, 20217, 20883, 26032}),
#              (678, {1716, 9786, 10433, 22385, 25671, 26197}),
#              (844, {23665}),
#              (845, {11302}),
#              (846, {2566, 5271, 12760, 17489, 22049, 22367, 25957}),
#              (847, {98, 6845, 23655}),
#              (848, {1797, 3803, 5554, 17998}),
#              (849, {3530, 7344, 22508, 23412}),
#              (850, {19731, 22339, 23445, 25445}),
#              (851,
#               {2863, 3194, 3434, 14578, 14744, 16182, 21146, 22593, 25307}),
#              (852, {2318, 24244, 25517}),
#              (853, {3166, 17741, 20759}),
#              (854, {6488, 6974, 10266, 11630, 13399, 15936, 19122}),
#              (855, {5236, 17245, 18972, 25444, 26017}),
#              (856, {4739, 9879, 11716, 24539}),
#              (857, {3596, 9052, 19346, 20586, 23872}),
#              (858, {198, 4995, 8478, 14067, 19782}),
#              (859,
#               {2094,
#                3600,
#                10329,
#                14251,
#                14630,
#                15126,
#                15940,
#                21744,
#                22994,
#                23215,
#                23237}),
#              (860, {2836, 13159, 15383, 21878}),
#              (861, {10306, 25863}),
#              (862, {18852, 19736}),
#              (863, {7096, 13118, 13415, 16001, 18048}),
#              (864,
#               {1589,
#                8021,
#                8082,
#                10832,
#                11063,
#                13761,
#                17217,
#                18813,
#                19423,
#                24305,
#                25120}),
#              (865, {21327, 24688, 26482}),
#              (866, {6514, 6833, 9222, 20720, 25491}),
#              (867, {1152}),
#              (868, {999, 11210}),
#              (869, {2861, 7694, 17927, 18411}),
#              (870, {25484}),
#              (871, {5025, 10589, 24456}),
#              (872, set()),
#              (873, {3812, 8332, 16869, 18959, 24747}),
#              (874, {7733, 17314, 20373}),
#              (875, {7760}),
#              (876, {7978, 12617, 15406}),
#              (877,
#               {3380, 5586, 8067, 9353, 10702, 12160, 12764, 22538, 23631}),
#              (878, {4357, 16369}),
#              (879, {2257, 5683, 12809}),
#              (880, {5877, 12313, 19477, 24220, 24511}),
#              (881, {2383, 4418, 22598}),
#              (882, {10890, 17858}),
#              (883, {2551, 22544}),
#              (884, {15451, 16644, 25639}),
#              (885,
#               {223,
#                320,
#                568,
#                631,
#                659,
#                1352,
#                1911,
#                2107,
#                2248,
#                3046,
#                3092,
#                3443,
#                4451,
#                5075,
#                5422,
#                6512,
#                6765,
#                7073,
#                7158,
#                7243,
#                7650,
#                8027,
#                8249,
#                8463,
#                8651,
#                9045,
#                10067,
#                10713,
#                11121,
#                11140,
#                11337,
#                13171,
#                13328,
#                13820,
#                14077,
#                14268,
#                14663,
#                14947,
#                15350,
#                16154,
#                16520,
#                17496,
#                18982,
#                19131,
#                19380,
#                20262,
#                20579,
#                20838,
#                21152,
#                21705,
#                21707,
#                21842,
#                22660,
#                23720,
#                24483,
#                24536,
#                24741,
#                26297,
#                26464,
#                26565}),
#              (886, {20891}),
#              (887, {985, 1178, 12322, 22901, 25522}),
#              (888, {5171, 6060, 9094, 11000}),
#              (889, {18086}),
#              (890, {9093, 25748}),
#              (891, {2852, 20566, 21435, 25212}),
#              (892, {2548, 19944}),
#              (893, {12198, 24982}),
#              (894, {9854, 20654}),
#              (895, {22415, 24024, 25545, 25884}),
#              (974, {6889}),
#              (975, {3893, 5418, 15193, 17249, 19416}),
#              (976, set()),
#              (977, {4764, 8450}),
#              (978, {1362, 7719}),
#              (979, {1983, 6538, 12088, 12476, 13459, 15599, 23739}),
#              (980, {10570, 14304, 16516}),
#              (981, {4253, 17190}),
#              (982, {16841}),
#              (983, {4700, 6962, 13049, 19302, 25798}),
#              (984, {3787, 19567, 25089}),
#              (985, {887, 1178, 8560, 12322, 22901, 22961, 25067, 25522}),
#              (986, {4228, 15565, 16940, 22644}),
#              (987, {1613, 12752, 14547}),
#              (988, set()),
#              (989, {5743}),
#              (990, {7090, 7774, 13197, 26589}),
#              (991, {767, 4375, 6257, 7311, 25503}),
#              (992, {15297, 19818}),
#              (993, {3664, 5930, 14883, 19947}),
#              (994, {1313, 12742}),
#              (995, {9191, 25257}),
#              (996, {9331, 20746}),
#              (997, {1645, 11447}),
#              (998, {13269, 16376, 16657, 19100, 19530}),
#              (999, {868, 11210}),
#              ...])

# %%
adj_list = [[0 for i in range(len(adj1))] for i in range(len(adj1))]
for key in adj1:
    for val in adj1[key]:
        adj_list[key][val] = 1

# %%
from collections import OrderedDict
def degree(matrix,i):
    count = 0
    for j in range(len(matrix[i])):
        if matrix[i][j] != 0:
            count = count + 1
    return count
def create_list(ei, ej, matrix):
    adjL = []
    adj_map = {}
    for i in range(len(matrix)):
        adj_map[i] = []
        adjL.append([])
    m = len(ei)
    for i in range(m):
        u = ei[i]
        v = ej[i]
        adj_map[u].append(v)
        adjL[u].append(v)
    return adjL, adj_map
def create_enchanced(mat1, mat2):
    for i in range(len(mat1)):
        for nodeStep in mat1[i]:
            for node in mat1[nodeStep]:
                if (node != i) & (node not in mat2[i]):
                    mat2[i].append(node)
    return mat2
def cohesionCentrality(adj_list,edge_i, edge_j):
    inf = {}
    for i in range(len(adj_list)):
        deg = degree(adj_list, i)
        inf[i] = deg
    tolerance = 0.5
    blacklist = (int) (tolerance * len(adj_list))
    bl = []
    sl = []
    inf_sorted = sorted(inf.items(), key=lambda kv: kv[1])
    inf1 = OrderedDict()
    for x in inf_sorted:
        key = x[0]
        value = x[1]
        inf1[key] = value
    black = inf1.keys()
    j=0
    for i in black:
        if j <  blacklist:
            bl.append(i)
        elif j >= blacklist:
            sl.append(i)
        j = j + 1
    #Cohesion Algo Begins
    edge = []
    for i in range(len(edge_i)):
        edge.append((edge_i[i], edge_j[i]))
    for x in range(5):
        for i in edge:
            if i[0] in bl:
                edge.remove(i)
        for i in edge:
            if i[1] in bl:
                edge.remove(i)
    edge_i = []
    edge_j = []
    for i in edge:
        edge_i.append(i[0])
        edge_j.append(i[1])
    adjL1,adj_map1 = create_list(edge_i, edge_j, adj_list)
    adjL2,adj_map2 = create_list(edge_i, edge_j, adj_list)
    adjL3,adj_map3 = create_list(edge_i, edge_j, adj_list)
    adjL4,adj_map4 = create_list(edge_i, edge_j, adj_list)
    adjL5,adj_map5 = create_list(edge_i, edge_j, adj_list)
    adj_map2 = create_enchanced(adj_map1, adj_map2)
    adj_map3 = create_enchanced(adj_map2, adj_map3)
    lll = []
    for i in range(len(adjL3)):
        lll.append(len(adjL3[i]))
    mp = {}
    for i in range(len(lll)):
        if lll[i] != 0:
            mp[i] = lll[i]
    master = [0] * len(adj_list)
    count_0 = []
    count_2 = []
    count_3 = []
    count_4 = []
    for lst in adjL1:
        count_0.append(len(lst))
    for lst in adjL3:
        count_2.append(len(lst))
    threshold = 0.3
    for i in range(len(count_0)):
        if (count_0[i] !=0) & (count_2[i] != 0):
            if (float(count_0[i]) / float(count_2[i])) < threshold:
                master[i] = count_2[i]
                adjL3[i].clear()
                adjL4[i].clear()
                adjL5[i].clear()
    adj_map4 = create_enchanced(adj_map3, adj_map4)
    for lst in adjL4:
        count_3.append(len(lst))
    for i in range(len(count_0)):
        if (count_0[i] !=0) & (count_3[i] != 0):
            if (float(count_0[i]) / float(count_3[i])) < threshold:
                master[i] = count_3[i]
                adjL4[i].clear()
                adjL5[i].clear()
    adj_map5 = create_enchanced(adj_map4, adj_map5)
    for lst in adjL5:
        count_4.append(len(lst))
    for i in range(len(count_0)):
        if (count_0[i] !=0) & (count_4[i] != 0):
            if (float(count_0[i]) / float(count_4[i])) < threshold:
                master[i] = count_4[i]
                adjL5[i].clear()
        elif (count_0[i] !=0) & (count_4[i] != 0):
            if (float(count_0[i]) / float(count_4[i])) > threshold:
                master[i] = count_4[i]
    for index in range(len(master)):
        if master[index] == 0:
            master[index] = inf[index]
    return master

# %%
edge_i = []
edge_j = []
for i in range(len(adj_list)):
    for j in range(len(adj_list)):
        if adj_list[i][j] != 0:
            edge_i.append(i)
            edge_j.append(j)

# %%
master = cohesionCentrality(adj_list, edge_i, edge_j)
index = -1
max_influence = 0
for i in range(len(master)):
    if master[i] > max_influence:
        max_influence = master[i]
        index = i
for key, value in name_map.items():
    if value == index:
        print(key)
# Out:
# Matthias Samwald

# %%
max_influence
# Out:
# 68

# %%
import numpy as np
df = pd.DataFrame(np.column_stack([edge_i, edge_j]), columns=['node1', 'node2'])
adj_list1 = adj_list.copy()
df['weight'] = np.ones(len(df))
df['weight'] = df['weight'].astype(int)
df.to_csv('list.csv', index = False, header = False)

# %%
import networkx as nx
graph = nx.from_pandas_edgelist(df, 'node1', 'node2')
pr = nx.pagerank(graph, alpha=0.5)
author_pagerank = {}
for key in name_map:
    v = name_map[key]
    if v not in pr:
        author_pagerank[key] = 0
    else:
        author_pagerank[key] = pr[v]

# %%
train = pd.DataFrame(columns=['num_papers', 'num_citations','page_rank_score'])
train['num_papers'] = pd.Series(author_to_papersum)
train['num_citations'] = pd.Series(author_to_papercite)
train['page_rank_score'] = pd.Series(author_pagerank)
train['sociability'] = pd.Series(sociability)
train['longevity'] = pd.Series(longevity)
train['h-index'] = pd.Series(atoh1)
train['diversity'] = pd.Series(diversity)

# %%
len(author_to_papercite)
# Out:
# 26699

# %%
X_train , X_test, Y_train , Y_test = model_selection.train_test_split(
    train, master, test_size=0.25, random_state = 5)
lr = LinearRegression()
model = lr.fit(X_train, Y_train)
train_score = lr.predict(X_train)
test_score = lr.predict(X_test)
mean_squared_error(Y_test, test_score)
# Out:
# 9.361304062628566

# %%
import lightgbm as lgb
X_train , X_test, Y_train , Y_test = model_selection.train_test_split(
    train, master, test_size=0.25, random_state = 5)
params_lgb = {"objective" : "regression", "metric" : "rmse", "bagging_fraction" : 0.76, "feature_fraction" : 0.8, "bagging_frequency" : 6,
            "num_leaves" : 35, "learning_rate" : 0.06 }
reg = lgb.LGBMRegressor(
       n_estimators=1000,
       subsample=.9,
       colsample_bytree=.9,
       random_state=1,
       **params_lgb
)
prediction_model = reg.fit(
       X_train, Y_train,
       eval_set=[(X_test, Y_test)],
       early_stopping_rounds=150,
       verbose = 100,
       eval_metric='rmse'
)
# Out:
# Training until validation scores don't improve for 150 rounds.
# [100]	valid_0's rmse: 1.76147
# [200]	valid_0's rmse: 1.7246
# [300]	valid_0's rmse: 1.70977
# [400]	valid_0's rmse: 1.70079
# [500]	valid_0's rmse: 1.69199
# [600]	valid_0's rmse: 1.6894
# [700]	valid_0's rmse: 1.6849
# [800]	valid_0's rmse: 1.6788
# [900]	valid_0's rmse: 1.67338
# [1000]	valid_0's rmse: 1.67136
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 1.67136

# %%
predictions = lr.predict(train)

# %%
train
# Out:
#                            num_papers  num_citations  page_rank_score  \
# Ehsan Samei                         1              0         0.000039
# Jean-Luc Minel                      1              1         0.000039
# Byung-Gil Lee                       1             50         0.000039
# Vic Gulas                           1              6         0.000039
# Thomas A. Richmond                  1              1         0.000039
# Victor Chepoi                       1              2         0.000039
# Michael Schwarz                     1             50         0.000038
# Kaisar Imam                         1             50         0.000039
# Yukiyasu Shimada                    1              0         0.000039
# Ning Gu                             1              1         0.000039
# Dirk Vandermeulen                   1              7         0.000039
# Ting Yuan                           1             18         0.000033
# Mohammed ElHelw                     1             50         0.000039
# Guojin Wang                         1              0         0.000000
# Curtis Dyreson                      1              5         0.000035
# Claus-Uwe Linster                   1             18         0.000039
# Oliver Rod                          1              3         0.000039
# Xiaohe Wu                           1              5         0.000036
# Norbert Essl                        1              0         0.000029
# Michael Vanden Boom                 1             50         0.000039
# Angelo Masi                         1              5         0.000038
# Wai Ching Tsui                      1              6         0.000040
# Nan Zhang                           2             50         0.000054
# Thomas Heinis                       1              4         0.000039
# Javier Barandiarán                  1              0         0.000039
# Bartłomiej Maǥachowski              1             50         0.000029
# Dennis M. Steininger                2             18         0.000032
# Liang Liu                           1              0         0.000039
# Hans Jürgen Bacher                  1              9         0.000039
# Harald Hoppe                        1              0         0.000038
# ...                               ...            ...              ...
# Fadi Dornaika                       1              0         0.000039
# Petr Sgall                          1              0         0.000039
# Bo Guo                              1              0         0.000039
# Konstantina Galbogini               1             82         0.000037
# Norihide Kitaoka                    1             13         0.000039
# Hong Liu Liu                        1             50         0.000039
# Sabina Jeschke                      2             50         0.000056
# Patrick E. O'Neil                   1             26         0.000040
# Carl Frelicot                       1              6         0.000039
# Bilal Hameed                        1              5         0.000037
# William B. Thompson                 1             11         0.000039
# Piotr Hoffmann                      1             50         0.000039
# Jorge Teixeira                      1             10         0.000039
# David C. Gartrell                   1              0         0.000000
# Dat Tran                            3             62         0.000064
# Fabio Fioravanti                    1             21         0.000039
# Damian Markham                      1              5         0.000039
# Liu Zhi-hong                        1             50         0.000039
# Bing Xu                             1             50         0.000039
# Yuki Onodera                        1              0         0.000026
# Philipp Singer                      1             20         0.000039
# Luca Chittaro                       1             32         0.000039
# Qiang Niu                           1              0         0.000039
# Tsai-Cheng Wang                     1              6         0.000039
# S. Sitharama Iyengar                2             18         0.000053
# Choong Seon Hong                    1             50         0.000039
# Ana-Maria Olteanu-Raimond           1              4         0.000039
# Qinxiang Wang                       1              0         0.000036
# Jin Xiao                            1              5         0.000032
# V. I. Romanov                       1              0         0.000039
#
#                            sociability  longevity  h-index  diversity
# Ehsan Samei                   1.000000          1        0          1
# Jean-Luc Minel                1.000000          1        1          1
# Byung-Gil Lee                 1.000000          1        1          1
# Vic Gulas                     1.000000          1        1          1
# Thomas A. Richmond            1.000000          1        1          1
# Victor Chepoi                 1.000000          1        1          1
# Michael Schwarz               1.000000          1        1          1
# Kaisar Imam                   1.000000          1        1          1
# Yukiyasu Shimada              1.000000          1        0          1
# Ning Gu                       1.000000          1        1          1
# Dirk Vandermeulen             1.000000          1        1          1
# Ting Yuan                     1.000000          1        1          1
# Mohammed ElHelw               1.000000          1        1          1
# Guojin Wang                   1.000000          1        0          1
# Curtis Dyreson                1.000000          1        1          1
# Claus-Uwe Linster             1.000000          1        1          1
# Oliver Rod                    1.000000          1        1          1
# Xiaohe Wu                     1.000000          1        1          1
# Norbert Essl                  1.000000          1        0          1
# Michael Vanden Boom           1.000000          1        1          1
# Angelo Masi                   1.000000          1        1          1
# Wai Ching Tsui                1.000000          1        1          1
# Nan Zhang                     1.000000          1        1          2
# Thomas Heinis                 1.000000          1        1          1
# Javier Barandiarán            1.000000          1        0          1
# Bartłomiej Maǥachowski        1.000000          1        1          1
# Dennis M. Steininger          2.386294          1        2          2
# Liang Liu                     1.000000          1        0          1
# Hans Jürgen Bacher            1.000000          1        1          1
# Harald Hoppe                  1.000000          1        0          1
# ...                                ...        ...      ...        ...
# Fadi Dornaika                 1.000000          1        0          1
# Petr Sgall                    1.000000          1        0          1
# Bo Guo                        1.000000          1        0          1
# Konstantina Galbogini         1.000000          1        1          1
# Norihide Kitaoka              1.000000          1        1          1
# Hong Liu Liu                  1.000000          1        1          1
# Sabina Jeschke                1.000000          3        1          2
# Patrick E. O'Neil             1.000000          1        1          1
# Carl Frelicot                 1.000000          1        1          1
# Bilal Hameed                  1.000000          1        1          1
# William B. Thompson           1.000000          1        1          1
# Piotr Hoffmann                1.000000          1        1          1
# Jorge Teixeira                1.000000          1        1          1
# David C. Gartrell             1.000000          1        0          1
# Dat Tran                      1.693147          3        2          3
# Fabio Fioravanti              1.000000          1        1          1
# Damian Markham                1.000000          1        1          1
# Liu Zhi-hong                  1.000000          1        1          1
# Bing Xu                       1.000000          1        1          1
# Yuki Onodera                  1.000000          1        0          1
# Philipp Singer                1.000000          1        1          1
# Luca Chittaro                 1.000000          1        1          1
# Qiang Niu                     1.000000          1        0          1
# Tsai-Cheng Wang               1.000000          1        1          1
# S. Sitharama Iyengar          1.000000          2        1          2
# Choong Seon Hong              1.000000          1        1          1
# Ana-Maria Olteanu-Raimond     1.000000          1        1          1
# Qinxiang Wang                 1.000000          1        0          1
# Jin Xiao                      1.000000          1        1          1
# V. I. Romanov                 1.000000          1        0          1
#
# [26699 rows x 7 columns]

# %%
predictions = predictions.tolist()

# %%
top_authors = {}
for index in range(len(predictions)):
    top_authors[name_map_reverse[index]] = predictions[index]

# %%
import operator
sorted_x = sorted(top_authors.items(), key=operator.itemgetter(1), reverse=True)

# %%
top_100_authors_model = sorted_x[:100]

# %%
from sklearn.model_selection import permutation_test_score
import matplotlib.pyplot as plt
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
score, permutation_scores, pvalue = permutation_test_score(lr, X_test, Y_test, n_permutations=500, n_jobs=1,scoring='neg_mean_squared_error')
plt.hist(permutation_scores, 50, label='Permutation scores',edgecolor='black')
ylim = plt.ylim()
plt.plot(2*[score], ylim, '--g', linewidth=3,label='Classification Score (pvalue %s)' % pvalue)
plt.ylim(ylim)
plt.legend()
plt.xlabel('Score')
plt.show()
# Out:
# /jet/var/python/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
pvalue
# Out:
# 0.001996007984031936

# %%
from scipy.stats.stats import pearsonr

# %%
sorted_x1 = sorted(atoh.items(), key=operator.itemgetter(1), reverse=True)
sorted_x2 = sorted(i10_index.items(), key=operator.itemgetter(1), reverse=True)
sorted_x3 = sorted(atog1.items(), key=operator.itemgetter(1), reverse=True)

# %%
top_100_authors_hindex = sorted_x1[:100]
top_100_authors_i10index = sorted_x2[:100]
top_100_authors_gindex = sorted_x3[:100]

# %%
model_aut = []
for i in top_100_authors_model:
    model_aut.append(i[0])
model_hin = []
for i in top_100_authors_hindex:
    model_hin.append(i[0])
model_i10in = []
for i in top_100_authors_i10index:
    model_i10in.append(i[0])
model_gin = []
for i in top_100_authors_gindex:
    model_gin.append(i[0])

# %%
common_with_hindex = []
for i in model_aut:
    if i in model_hin:
        common_with_hindex.append(i)

# %%
common_with_i10index = []
for i in model_aut:
    if i in model_i10in:
        common_with_i10index.append(i)

# %%
common_with_gindex = []
for i in model_aut:
    if i in model_gin:
        common_with_gindex.append(i)

# %%
len(common_with_hindex)
# Out:
# 26

# %%
len(common_with_i10index)
# Out:
# 22

# %%
len(common_with_gindex)
# Out:
# 38

# %%
h_index_values = train['h-index'].values.tolist()
pearsonr(predictions, h_index_values)
# Out:
# (0.36462380803622718, 0.0)

# %%
i10_index_values = []
for i in i10_index:
    i10_index_values.append(i10_index[i])

# %%
pearsonr(predictions, i10_index_values)
# Out:
# (0.26775479165897409, 0.0)

# %%
g_index_values = []
for i in atog1:
    g_index_values.append(atog1[i])

# %%
pearsonr(predictions, g_index_values)
# Out:
# (0.46316297696441033, 0.0)
